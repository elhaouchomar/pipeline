# %%
import numpy as np
from sklearn.impute import SimpleImputer

train_data = [[7, 6, 5],
              [4, np.nan, 5],
              [1, 20, 8]]

test_data = [[np.nan, 1, 2],
             [7, np.nan, 9],
             [np.nan, 2, 4]]

imputer = SimpleImputer(strategy='mean')
imputer.fit(train_data)

print(f"Imputer statistics: {imputer.statistics_}")
print(f"Numpy nanmean:      {np.nanmean(train_data, axis=0)}")

train_filled = imputer.transform(train_data)
test_filled = imputer.transform(test_data)
# Out:
# Imputer statistics: [ 4. 13.  6.]
# Numpy nanmean:      [ 4. 13.  6.]
